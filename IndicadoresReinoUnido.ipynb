# %% [markdown]
# <a href="https://colab.research.google.com/github/raulval9/PrimerPrueba/blob/main/IndicadoresReinoUnido.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##Importar librerias de donde se consulta la informacion
# !pip install world_bank_data
import world_bank_data as wb
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Collecting world_bank_data
#   Downloading world_bank_data-0.1.4-py2.py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from world_bank_data) (6.2.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from world_bank_data) (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from world_bank_data) (2.32.4)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas->world_bank_data) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->world_bank_data) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->world_bank_data) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->world_bank_data) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->world_bank_data) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->world_bank_data) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->world_bank_data) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->world_bank_data) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->world_bank_data) (1.17.0)
# Downloading world_bank_data-0.1.4-py2.py3-none-any.whl (10 kB)
# Installing collected packages: world_bank_data
# Successfully installed world_bank_data-0.1.4

# %%
##Definicion de variables
sns.set(style="whitegrid")

# Países de interés
countries = ["GB", "US", "MX", "EU"]

# %%
## Consulta de informacion de poblacion y grafico
# Indicador de población total
indicator = "SP.POP.TOTL"

# Descargar datos de los últimos 25 años
data = wb.get_series(indicator, country=countries, date="2000:2025")

# Reorganizar en un DataFrame
df = data.unstack(level=0)  # columnas = países, filas = años
df.index = df.index.droplevel("Series")

# Graficar
df_millions = df / 1e6

df_millions.plot(figsize=(10,6))

plt.title("Población (2000-2024)")
plt.ylabel("Millones de habitantes")  # 🔧 cambio aquí
plt.xlabel("Año")
plt.legend(title="País")
plt.grid(True)

plt.show()

# %%
## Consulta de informacion de "PIB constante US$"
# Indicador de PIB
indicator = "NY.GDP.MKTP.KD"

# Descargar datos de los últimos 25 años
data = wb.get_series(indicator, country=countries, date="2000:2025")

# Reorganizar en un DataFrame
df = data.unstack(level=0)  # columnas = países, filas = años
df.index = df.index.droplevel("Series")

# Graficar
df_millions = df / 1e9

df_millions.plot(figsize=(10,6))

plt.title("PIB (2000-2024)")
plt.ylabel("Miles de millones USD")  # 🔧 cambio aquí
plt.xlabel("Año")
plt.legend(title="País")
plt.grid(True)

plt.show()

# %%
## Consulta de informacion de "Crecimiento PIB % anual"
# Indicador de crecimiento PIB anual
indicator = "NY.GDP.MKTP.KD.ZG"

# Descargar datos de los últimos 25 años
data = wb.get_series(indicator, country=countries, date="2000:2025")

# Reorganizar en un DataFrame
df = data.unstack(level=0)  # columnas = países, filas = años
df.index = df.index.droplevel("Series")

# Graficar
df_millions = df / 1

df_millions.plot(figsize=(10,6))

plt.title("Crecimiento PIB (2000-2024)")
plt.ylabel("% PIB")  # 🔧 cambio aquí
plt.xlabel("Año")
plt.legend(title="País")
plt.grid(True)

plt.show()

# %%
## Consulta de informacion de "PIB per cápita constante US$"
# Indicador de PIB per capita
indicator = "NY.GDP.PCAP.KD"

# Descargar datos de los últimos 25 años
data = wb.get_series(indicator, country=countries, date="2000:2025")

# Reorganizar en un DataFrame
df = data.unstack(level=0)  # columnas = países, filas = años
df.index = df.index.droplevel("Series")

# Graficar
df_millions = df / 1e3

df_millions.plot(figsize=(10,6))

plt.title("Población (2000-2024)")
plt.ylabel("Miles USD")  # 🔧 cambio aquí
plt.xlabel("Año")
plt.legend(title="País")
plt.grid(True)

plt.show()

# %%
## Consulta de informacion de "INB precios actuales US$"
# Indicador deINB
indicator = "NY.GNP.MKTP.CD"

# Descargar datos de los últimos 25 años
data = wb.get_series(indicator, country=countries, date="2000:2025")

# Reorganizar en un DataFrame
df = data.unstack(level=0)  # columnas = países, filas = años
df.index = df.index.droplevel("Series")

# Graficar
df_millions = df / 1e9

df_millions.plot(figsize=(10,6))

plt.title("INB (2000-2024)")
plt.ylabel("Miles de millones USD")  # 🔧 cambio aquí
plt.xlabel("Año")
plt.legend(title="País")
plt.grid(True)

plt.show()

# %%
## Consulta de informacion de "Inflación IPC % anual"
# Indicador de inflación anual
indicator = "FP.CPI.TOTL.ZG"

# Descargar datos de los últimos 25 años
data = wb.get_series(indicator, country=countries, date="2000:2025")

# Reorganizar en un DataFrame
df = data.unstack(level=0)  # columnas = países, filas = años
df.index = df.index.droplevel("Series")

# Graficar
df_millions = df / 1

df_millions.plot(figsize=(10,6))

plt.title("Inflación (2000-2024)")
plt.ylabel("% Inflación")  # 🔧 cambio aquí
plt.xlabel("Año")
plt.legend(title="País")
plt.grid(True)

plt.show()

# %%
## Consulta de informacion de "Tasa participación laboral %"
# Indicador de participación laboral
indicator = "SL.TLF.CACT.ZS"

# Descargar datos de los últimos 25 años
data = wb.get_series(indicator, country=countries, date="2000:2025")

# Reorganizar en un DataFrame
df = data.unstack(level=0)  # columnas = países, filas = años
df.index = df.index.droplevel("Series")

# Graficar
df_millions = df / 1

df_millions.plot(figsize=(10,6))

plt.title("Participación laboral (2000-2024)")
plt.ylabel("% Participación")  # 🔧 cambio aquí
plt.xlabel("Año")
plt.legend(title="País")
plt.grid(True)

plt.show()

# %%
## Consulta de informacion de "Tasa desempleo %"
# Indicador de desempleo
indicator = "SL.UEM.TOTL.ZS"

# Descargar datos de los últimos 25 años
data = wb.get_series(indicator, country=countries, date="2000:2025")

# Reorganizar en un DataFrame
df = data.unstack(level=0)  # columnas = países, filas = años
df.index = df.index.droplevel("Series")

# Graficar
df_millions = df / 1

df_millions.plot(figsize=(10,6))

plt.title("Desempleo (2000-2024)")
plt.ylabel("% Desempleo")  # 🔧 cambio aquí
plt.xlabel("Año")
plt.legend(title="País")
plt.grid(True)

plt.show()

# %%
## Consulta de informacion de "Ingresos fiscales % PIB"
# Indicador de ingresos fiscales
indicator = "GC.TAX.TOTL.GD.ZS"

# Descargar datos de los últimos 25 años
data = wb.get_series(indicator, country=countries, date="2000:2025")

# Reorganizar en un DataFrame
df = data.unstack(level=0)  # columnas = países, filas = años
df.index = df.index.droplevel("Series")

# Graficar
df_millions = df / 1

df_millions.plot(figsize=(10,6))

plt.title("Ingresos fiscales en relación al PIB (2000-2024)")
plt.ylabel("% Ingresos / PIB")  # 🔧 cambio aquí
plt.xlabel("Año")
plt.legend(title="País")
plt.grid(True)

plt.show()

# %%
## Consulta de informacion de "Déficit/superávit % PIB"
# Indicador de déficit supervávit
indicator = "GC.BAL.CASH.GD.ZS"

# Descargar datos de los últimos 25 años
data = wb.get_series(indicator, country=countries, date="2000:2025")

# Reorganizar en un DataFrame
df = data.unstack(level=0)  # columnas = países, filas = años
df.index = df.index.droplevel("Series")

# Graficar
df_millions = df / 1

df_millions.plot(figsize=(10,6))

plt.title("Déficit / superávit vs PIB (2000-2024)")
plt.ylabel("% Déficit / PIB")  # 🔧 cambio aquí
plt.xlabel("Año")
plt.legend(title="País")
plt.grid(True)

plt.show()
# Out:
#   File "/tmp/ipykernel_817/2532079361.py", line 6
#     data = wb.get_series(indicator, country="US"", date="2000:2012")
#                                                                   ^
# SyntaxError: unterminated string literal (detected at line 6)

# %%
## Consulta de informacion de "Deuda pública % PIB"
# Indicador de deuda publica
indicator = "GC.DOD.TOTL.GD.ZS"

# Descargar datos de los últimos 25 años
data = wb.get_series(indicator, country=countries, date="2000:2025")

# Reorganizar en un DataFrame
df = data.unstack(level=0)  # columnas = países, filas = años
df.index = df.index.droplevel("Series")

# Graficar
df_millions = df / 1

df_millions.plot(figsize=(10,6))

plt.title("Deuda pública vs PIB (2000-2024)")
plt.ylabel("% Deuda / PIB")  # 🔧 cambio aquí
plt.xlabel("Año")
plt.legend(title="País")
plt.grid(True)

plt.show()

# %%
## Consulta de informacion de "Balanza comercial % PIB"
# Indicador de balanza comercial
indicator = "NE.RSB.GNFS.ZS"

# Descargar datos de los últimos 25 años
data = wb.get_series(indicator, country=countries, date="2000:2025")

# Reorganizar en un DataFrame
df = data.unstack(level=0)  # columnas = países, filas = años
df.index = df.index.droplevel("Series")

# Graficar
df_millions = df / 1

df_millions.plot(figsize=(10,6))

plt.title("Balanza comercial vs PIB (2000-2024)")
plt.ylabel("% Balanza / PIB")  # 🔧 cambio aquí
plt.xlabel("Año")
plt.legend(title="País")
plt.grid(True)

plt.show()

# %%
## Consulta de informacion de "Capitalización bursátil % PIB"
# Indicador de capitalización bursátil
indicator = "CM.MKT.LCAP.GD.ZS"

# Descargar datos de los últimos 25 años
data = wb.get_series(indicator, country=countries, date="2000:2025")

# Reorganizar en un DataFrame
df = data.unstack(level=0)  # columnas = países, filas = años
df.index = df.index.droplevel("Series")

# Graficar
df_millions = df / 1

df_millions.plot(figsize=(10,6))

plt.title("Capitalización bursátil vs PIB (2000-2024)")
plt.ylabel("% Capitalización / PIB")  # 🔧 cambio aquí
plt.xlabel("Año")
plt.legend(title="País")
plt.grid(True)

plt.show()

# %%
## Consulta de informacion de "Crédito doméstico % PIB"
# Indicador de créditos domésticos
indicator = "FS.AST.DOM.GD.ZS"

# Descargar datos de los últimos 25 años
data = wb.get_series(indicator, country=countries, date="2000:2025")

# Reorganizar en un DataFrame
df = data.unstack(level=0)  # columnas = países, filas = años
df.index = df.index.droplevel("Series")

# Graficar
df_millions = df / 1

df_millions.plot(figsize=(10,6))

plt.title("Créditos domésticos vs PIB (2000-2024)")
plt.ylabel("% Créditos / PIB")  # 🔧 cambio aquí
plt.xlabel("Año")
plt.legend(title="País")
plt.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/requests/models.py in json(self, **kwargs)
#     975         try:
# --> 976             return complexjson.loads(self.text, **kwargs)
#     977         except JSONDecodeError as e:
#
# /usr/local/lib/python3.12/dist-packages/simplejson/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, allow_nan, **kw)
#     513             and not use_decimal and not allow_nan and not kw):
# --> 514         return _default_decoder.decode(s)
#     515     if cls is None:
#
# /usr/local/lib/python3.12/dist-packages/simplejson/decoder.py in decode(self, s, _w, _PY3)
#     385             s = str(s, self.encoding)
# --> 386         obj, end = self.raw_decode(s)
#     387         end = _w(s, end).end()
#
# /usr/local/lib/python3.12/dist-packages/simplejson/decoder.py in raw_decode(self, s, idx, _w, _PY3)
#     415                 idx += 3
# --> 416         return self.scan_once(s, idx=_w(s, idx).end())
#
# JSONDecodeError: Expecting value: line 1 column 4 (char 3)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/world_bank_data/request.py in wb_get(*args, **kwargs)
#      73     try:
# ---> 74         data = response.json()
#      75     except ValueError:  # simplejson.errors.JSONDecodeError derives from ValueError
#
# /usr/local/lib/python3.12/dist-packages/requests/models.py in json(self, **kwargs)
#     979             # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980             raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     981
#
# JSONDecodeError: Expecting value: line 1 column 4 (char 3)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_817/3814452294.py in <cell line: 0>()
#       4
#       5 # Descargar datos de los últimos 25 años
# ----> 6 data = wb.get_series(indicator, country=countries, date="2000:2025")
#       7
#       8 # Reorganizar en un DataFrame
#
# /usr/local/lib/python3.12/dist-packages/world_bank_data/indicator.py in get_series(indicator, country, id_or_value, simplify_index, **params)
#      51     params["format"] = "jsonstat"
#      52
# ---> 53     idx = wb_get("country", country, "indicator", indicator, **params)
#      54     _, idx = idx.popitem()
#      55
#
# /usr/local/lib/python3.12/dist-packages/world_bank_data/request.py in wb_get(*args, **kwargs)
#      74         data = response.json()
#      75     except ValueError:  # simplejson.errors.JSONDecodeError derives from ValueError
# ---> 76         raise ValueError(
#      77             "{msg}\nurl={url}\nparams={params}".format(
#      78                 msg=_extract_message(response.text), url=url, params=params
#
# ValueError: The provided parameter value is not valid
# url=https://api.worldbank.org/v2/country/GB;US;MX;EU/indicator/FS.AST.DOM.GD.ZS
# params={'date': '2000:2025', 'format': 'jsonstat', 'per_page': 20000}

# %%
## Consulta de informacion de "Acciones negociadas % PIB"
# Indicador de acciones negociadas
indicator = "CM.MKT.TRAD.GD.ZS"

# Descargar datos de los últimos 25 años
data = wb.get_series(indicator, country=countries, date="2000:2025")

# Reorganizar en un DataFrame
df = data.unstack(level=0)  # columnas = países, filas = años
df.index = df.index.droplevel("Series")

# Graficar
df_millions = df / 1

df_millions.plot(figsize=(10,6))

plt.title("Acciones negociadas vs PIB (2000-2024)")
plt.ylabel("% Acciones / PIB")  # 🔧 cambio aquí
plt.xlabel("Año")
plt.legend(title="País")
plt.grid(True)

plt.show()

# %%
## Consulta de informacion de "Crédito al sector privado % PIB"
# Indicador de créditos al sector privado
indicator = "FS.AST.PRVT.GD.ZS"

# Descargar datos de los últimos 25 años
data = wb.get_series(indicator, country=countries, date="2000:2025")

# Reorganizar en un DataFrame
df = data.unstack(level=0)  # columnas = países, filas = años
df.index = df.index.droplevel("Series")

# Graficar
df_millions = df / 1

df_millions.plot(figsize=(10,6))

plt.title("Créditos al sector privado vs PIB (2000-2024)")
plt.ylabel("% Créditos / PIB")  # 🔧 cambio aquí
plt.xlabel("Año")
plt.legend(title="País")
plt.grid(True)

plt.show()

# %%
## Consulta de informacion de "Capital bancario / activos %"
# Indicador de capital bancario
indicator = "BN.CAP.RATIO.ZS"

# Descargar datos de los últimos 25 años
data = wb.get_series(indicator, country=countries, date="2000:2025")

# Reorganizar en un DataFrame
df = data.unstack(level=0)  # columnas = países, filas = años
df.index = df.index.droplevel("Series")

# Graficar
df_millions = df / 1

df_millions.plot(figsize=(10,6))

plt.title("Capital bancario vs activos (2000-2024)")
plt.ylabel("% Capital / activos")  # 🔧 cambio aquí
plt.xlabel("Año")
plt.legend(title="País")
plt.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/requests/models.py in json(self, **kwargs)
#     975         try:
# --> 976             return complexjson.loads(self.text, **kwargs)
#     977         except JSONDecodeError as e:
#
# /usr/local/lib/python3.12/dist-packages/simplejson/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, allow_nan, **kw)
#     513             and not use_decimal and not allow_nan and not kw):
# --> 514         return _default_decoder.decode(s)
#     515     if cls is None:
#
# /usr/local/lib/python3.12/dist-packages/simplejson/decoder.py in decode(self, s, _w, _PY3)
#     385             s = str(s, self.encoding)
# --> 386         obj, end = self.raw_decode(s)
#     387         end = _w(s, end).end()
#
# /usr/local/lib/python3.12/dist-packages/simplejson/decoder.py in raw_decode(self, s, idx, _w, _PY3)
#     415                 idx += 3
# --> 416         return self.scan_once(s, idx=_w(s, idx).end())
#
# JSONDecodeError: Expecting value: line 1 column 4 (char 3)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/world_bank_data/request.py in wb_get(*args, **kwargs)
#      73     try:
# ---> 74         data = response.json()
#      75     except ValueError:  # simplejson.errors.JSONDecodeError derives from ValueError
#
# /usr/local/lib/python3.12/dist-packages/requests/models.py in json(self, **kwargs)
#     979             # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980             raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     981
#
# JSONDecodeError: Expecting value: line 1 column 4 (char 3)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_817/2194170022.py in <cell line: 0>()
#       4
#       5 # Descargar datos de los últimos 25 años
# ----> 6 data = wb.get_series(indicator, country=countries, date="2000:2025")
#       7
#       8 # Reorganizar en un DataFrame
#
# /usr/local/lib/python3.12/dist-packages/world_bank_data/indicator.py in get_series(indicator, country, id_or_value, simplify_index, **params)
#      51     params["format"] = "jsonstat"
#      52
# ---> 53     idx = wb_get("country", country, "indicator", indicator, **params)
#      54     _, idx = idx.popitem()
#      55
#
# /usr/local/lib/python3.12/dist-packages/world_bank_data/request.py in wb_get(*args, **kwargs)
#      74         data = response.json()
#      75     except ValueError:  # simplejson.errors.JSONDecodeError derives from ValueError
# ---> 76         raise ValueError(
#      77             "{msg}\nurl={url}\nparams={params}".format(
#      78                 msg=_extract_message(response.text), url=url, params=params
#
# ValueError: The provided parameter value is not valid
# url=https://api.worldbank.org/v2/country/GB;US;MX;EU/indicator/BN.CAP.RATIO.ZS
# params={'date': '2000:2025', 'format': 'jsonstat', 'per_page': 20000}

# %%
## Consulta de informacion de "Préstamos no productivos %"
# Indicador de préstamos no productivos
indicator = "FB.AST.NPER.ZS"

# Descargar datos de los últimos 25 años
data = wb.get_series(indicator, country=countries, date="2000:2025")

# Reorganizar en un DataFrame
df = data.unstack(level=0)  # columnas = países, filas = años
df.index = df.index.droplevel("Series")

# Graficar
df_millions = df / 1

df_millions.plot(figsize=(10,6))

plt.title("Préstamos no productivos (2000-2024)")
plt.ylabel("% Préstamos")  # 🔧 cambio aquí
plt.xlabel("Año")
plt.legend(title="País")
plt.grid(True)

plt.show()
